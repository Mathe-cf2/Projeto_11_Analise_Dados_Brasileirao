# %% [markdown]
# ### 1. Importação de Bibliotecas
# Realize a importação da biblioteca pandas.

# %%
### importando a biblioteca pandas
import pandas as pd

# %% [markdown]
# ### 2. Importação da Base de Dados
#
# Importe o arquivo 'Tabela_Clubes.csv' o transforme em um dataframe e mostre as informações.

# %%
### carregando o arquivo CSV em um DataFrame
df = pd.read_csv('Tabela_Clubes.csv')

### mostrando as informações gerais do DataFrame
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Ano            200 non-null    int64
#  1   Pos.           200 non-null    int64
#  2   Clubes         200 non-null    str
#  3   Vitorias       200 non-null    int64
#  4   Derrotas       200 non-null    int64
#  5   Empates        200 non-null    int64
#  6   GolsF/S        200 non-null    str
#  7   Saldo          200 non-null    int64
#  8   Qtd_Jogadores  200 non-null    int64
#  9   Idade_Media    200 non-null    str
#  10  Estrangeiros   200 non-null    int64
#  11  Valor_total    200 non-null    int64
#  12  Media_Valor    200 non-null    int64
#  13  Unnamed: 13    1 non-null      float64
#  14  Unnamed: 14    1 non-null      float64
#  15  Unnamed: 15    1 non-null      str
#  16  Unnamed: 16    1 non-null      float64
# dtypes: float64(3), int64(10), str(4)
# memory usage: 30.1 KB

# %% [markdown]
# ### 3. Mostre as primeiras linhas do DataFrame

# %%
### mostrando as primeiras linhas do DataFrame
df.head()
# Out:
#     Ano  Pos.        Clubes  Vitorias  Derrotas  Empates GolsF/S  Saldo  \
# 0  2017    18    America-MG        10        10       18   30:47    -17
# 1  2017     7  Athletico-PR        16         9       13   54:37     17
# 2  2017     6   Atletico-MG        17         8       13   56:43     13
# 3  2017    11         Bahia        12        12       14   39:41     -2
# 4  2017     9      Botafogo        13        12       13   38:46     -8
#
#    Qtd_Jogadores Idade_Media  Estrangeiros  Valor_total  Media_Valor  \
# 0             51        24,8             0     27350000       536000
# 1             52          24             3     37650000       724000
# 2             50        23,4             6     61350000      1230000
# 3             48        23,2             2     34900000       727000
# 4             45        23,1             4     25550000       568000
#
#    Unnamed: 13  Unnamed: 14 Unnamed: 15  Unnamed: 16
# 0          NaN          NaN         NaN          NaN
# 1          NaN          NaN         NaN          NaN
# 2          NaN          NaN         NaN          NaN
# 3          NaN          NaN         NaN          NaN
# 4          NaN          NaN         NaN          NaN

# %% [markdown]
# ### 4. Removendo Colunas sem informações.

# %%
### Se observamos bem, podemos ver que temos quatro colounas sem nome e sem informações, ou seja valores nulos
### removendo as colunas sem nome
df = df.drop(columns=['Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16'])
### mostrando as informações gerais do DataFrame após a remoção das colunas
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Ano            200 non-null    int64
#  1   Pos.           200 non-null    int64
#  2   Clubes         200 non-null    str
#  3   Vitorias       200 non-null    int64
#  4   Derrotas       200 non-null    int64
#  5   Empates        200 non-null    int64
#  6   GolsF/S        200 non-null    str
#  7   Saldo          200 non-null    int64
#  8   Qtd_Jogadores  200 non-null    int64
#  9   Idade_Media    200 non-null    str
#  10  Estrangeiros   200 non-null    int64
#  11  Valor_total    200 non-null    int64
#  12  Media_Valor    200 non-null    int64
# dtypes: int64(10), str(3)
# memory usage: 23.8 KB

# %% [markdown]
# ### 5. Quais os times aparecem na tabela e quantas vezes cada um aparece?

# %%
### vamos ver quais os times aparecem na tabela e quantas vezes cada um aparece
print(df["Clubes"].value_counts())
# Out:
# Clubes
# Atletico-MG      10
# Corinthians      10
# Cruzeiro         10
# Flamengo         10
# Fluminense       10
# Gremio           10
# Santos           10
# Sao Paulo        10
# Athletico-PR      9
# Botafogo          9
# Internacional     9
# Palmeiras         9
# Coritiba          8
# Sport             7
# Vasco             7
# Vitoria           7
# Bahia             6
# Chapecoense       5
# Avai              5
# Ponte Preta       5
# Figueirense       5
# Goias             5
# Atletico-GO       4
# America-MG        3
# Ceara             3
# Nautico           3
# Criciuma          2
# Portuguesa        2
# Prudente          2
# Parana            1
# Santa Cruz        1
# Joinville         1
# Guarani           1
# Santo Andre       1
# Name: count, dtype: int64

# %% [markdown]
# ### 6. Quantos times diferentes temos no DataFrame?

# %%
### vamos contar o total de times únicos na tabela
clubes = (df["Clubes"].nunique())  #Nunique conta quantos valores difrentes existem

print(f"Existem {clubes} times difrentes ")
# Out:
# Existem 34 times difrentes

# %% [markdown]
# ### 7. Quais os anos que aparecem no DataFrame?

# %%
### vamos ver quais anos aparecem na tabela
df["Ano"].value_counts()
### vamos ordenar os anos de forma crescente
df = df.sort_values("Ano")
df
# Out:
#       Ano  Pos.       Clubes  Vitorias  Derrotas  Empates GolsF/S  Saldo  \
# 192  2008    19      Nautico        10         8       20   48:71    -23
# 193  2008     5    Palmeiras        17        11       10   58:45     13
# 194  2008    11     Prudente        12        13       13   59:52      7
# 195  2008    18  Santo Andre        11         8       19   46:61    -15
# 184  2008    10  Corinthians        14        10       14   50:54     -4
# ..    ...   ...          ...       ...       ...      ...     ...    ...
# 0    2017    18   America-MG        10        10       18   30:47    -17
# 4    2017     9     Botafogo        13        12       13   38:46     -8
# 5    2017    15        Ceara        10        14       14   32:38     -6
# 6    2017    14  Chapecoense        11        11       16   34:50    -16
# 7    2017    13  Corinthians        11        11       16   34:35     -1
#
#      Qtd_Jogadores Idade_Media  Estrangeiros  Valor_total  Media_Valor
# 192             33        24,1             2     15250000       462000
# 193             34          23             2     30550000       899000
# 194             35        24,5             1      2350000        67000
# 195             43        25,1             3      6230000       145000
# 184             33        22,8             1     43080000      1310000
# ..             ...         ...           ...          ...          ...
# 0               51        24,8             0     27350000       536000
# 4               45        23,1             4     25550000       568000
# 5               54          26             2     26950000       499000
# 6               52        24,8             5     32030000       616000
# 7               54        24,3             6     61400000      1140000
#
# [200 rows x 13 columns]

# %% [markdown]
# ### 8. Quais os campeões de cada ano?

# %%
### vamos verificar os campeões de cada ano e ordenar por ano

campeoes = df[df["Pos."] == 1].sort_values("Ano")

campeoes
# Out:
#       Ano  Pos.       Clubes  Vitorias  Derrotas  Empates GolsF/S  Saldo  \
# 187  2008     1     Flamengo        19        10        9   58:44     14
# 169  2009     1   Fluminense        20        11        7   62:36     26
# 148  2010     1  Corinthians        21         8        9   53:36     17
# 129  2011     1   Fluminense        22        11        5   61:33     28
# 107  2012     1     Cruzeiro        23         7        8   77:37     40
# 88   2013     1     Cruzeiro        24         8        6   67:38     29
# 64   2014     1  Corinthians        24         9        5   71:31     40
# 53   2015     1    Palmeiras        24         8        6   62:32     30
# 27   2016     1  Corinthians        21         9        8   50:30     20
# 13   2017     1    Palmeiras        23        11        4   64:26     38
#
#      Qtd_Jogadores Idade_Media  Estrangeiros  Valor_total  Media_Valor
# 187             35        23,3             4     50400000      1440000
# 169             50        23,5             4     42950000       859000
# 148             51        23,6             4     69700000      1370000
# 129             40        22,8             4     44200000      1110000
# 107             44        24,4             1     15100000       343000
# 88              32        25,7             4     41950000      1310000
# 64              36        24,8             4     52850000      1470000
# 53              38        25,9             4     69950000      1840000
# 27              41        23,4             3     49500000      1210000
# 13              48        24,8             4     88330000      1840000

# %% [markdown]
# ### 9. Qual o time que foi mais vezes campeão?

# %%
### qual time apareceu mais vezes como campeão?
campeoes = df[df["Pos."] == 1].sort_values("Vitorias")
contagem = campeoes["Clubes"].value_counts()

contagem
# Out:
# Clubes
# Corinthians    3
# Fluminense     2
# Cruzeiro       2
# Palmeiras      2
# Flamengo       1
# Name: count, dtype: int64

# %% [markdown]
# ### 10. Agora uma piada 😄, quais times paulistas não aparecem nenhuma vez como campeão?
#
# Responda com um print

# %%
### seu código aqui
print("São Paulo, Santos")
# Out:
# Figuerense

# %% [markdown]
# ### 11. Qual o time com mais derrotas?

# %%
### qual o time com mais derrotas?
derrotas = df.groupby("Clubes")["Derrotas"].sum().sort_values(ascending=False)

df[df["Clubes"] == time]

derrotas

### mostrando todas as informações do time com mais derrotas

time = derrotas.index[0]
derrotas_totais = derrotas.iloc[0]

print(f"{time}, derrotas:{derrotas_totais}")
# Out:
# Flamengo, derrotas:115

# %% [markdown]
# ### 12. Qual o time com menos derrotas?

# %%
### qual o time com menos derrotas?
menos_derrotas = derrotas = df.groupby("Clubes")["Derrotas"].sum().sort_values()

menos_derrotas

time = menos_derrotas.index[0]
menos_derrotas1 = menos_derrotas.iloc[0]

### mostrando todas as informações do time com menos derrotas
print(f"O Time que obteve menos derrotas foi o {time}, com um total de {menos_derrotas1} derrotas.")
# Out:
# O Time que obteve menos derrotas foi o Santa Cruz, com um total de 7 derrotas.

# %% [markdown]
# ### 13. Qual o time com maior número de estrangeiros?

# %%
### qual o time com maior número de estrangeiros?
maior_estrangeiros = df.groupby("Clubes")["Estrangeiros"].sum().sort_values(ascending=False)

time = maior_estrangeiros.index[0]
maior_estrangeiros1 = maior_estrangeiros.iloc[0]

### mostrando todas as informações do time com mais estrangeiros
print(f"O time que possui maior núemro de estrangeiros é o {time} sendo {maior_estrangeiros1} de estrangeiros ")
# Out:
# O time que possui maior núemro de estrangeiros é o Flamengo sendo 54 de estrangeiros

# %% [markdown]
# ### 14. qual o time com o menor número de estrangeiros?

# %%
### qual o time com menor número de estrangeiros?
menor_estrangeiros = df.groupby("Clubes")["Estrangeiros"].sum().sort_values()

time = menor_estrangeiros.index[0]
menor_estrangeiros = menor_estrangeiros.iloc[0]

print(f"O time que possui menor número de estrangeiros e o {time}, com um total de apenas {menor_estrangeiros} de estrangeiros")
# Out:
# O time que possui menor número de estrangeiros e o Atletico-GO, com um total de apenas 0 de estrangeiros

# %% [markdown]
# ### 15. Bônus
#
# Vamos criar um gráfico que mostre os maiores campeões presentes nessa base de dados

# %%
import matplotlib.pyplot as plt

# Vamos criar um gráfico de barras para visualizar os times com mais títulos
titulos = campeoes['Clubes'].value_counts()

plt.figure(figsize=(14, 8))
bars = plt.bar(titulos.index, titulos.values, 
               color=['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', 
                      '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf'],
               edgecolor='black', linewidth=0.5, alpha=0.8)

# Adicionar os valores em cima de cada barra
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height + 0.05,
             f'{int(height)}', ha='center', va='bottom', fontsize=10, fontweight='bold')

plt.title('Times com Mais Títulos', fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Clubes', fontsize=12, fontweight='bold')
plt.ylabel('Número de Títulos', fontsize=12, fontweight='bold')

# Ajustar a escala do eixo Y de 0 a 3
plt.ylim(0, 3)

# Melhorar a aparência dos eixos
plt.xticks(rotation=0, ha='right')
plt.yticks(range(0, 4))  # Apenas números inteiros de 0 a 3

# Adicionar grid para melhor leitura
plt.grid(axis='y', alpha=0.3, linestyle='--')

# Ajustar layout para evitar cortes
plt.tight_layout()

# Mostrar o gráfico
plt.show()
